# %%
import pandas as pd

# %%
df_exams = pd.read_csv('./StudentsPerformance.csv')

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1 Math Operations

# %% [markdown]
# ## 1.1 Operation in columns

# %%
# select a column and calculate total sum

df_exams['math score'].sum()
# Out:
# 66089

# %%
# count, mean, std, max and min

print(
    df_exams['math score'].count(),
    df_exams['math score'].mean(),
    df_exams['math score'].std(),
    df_exams['math score'].max(),
    df_exams['math score'].min()
)
# Out:
# 1000 66.089 15.163080096009468 100 0

# %%
# easier calculation with describe

df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## 1.2 Operations in rows

# %%
# calculating the sum in a row

row_sum = (df_exams['math score'] + df_exams['reading score'] + df_exams['writing score'])/3

# %%
df_exams1 = df_exams.copy()
df_exams1['average'] = row_sum

# %%
df_exams1.round(2).head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  average
# 0                    none          72             72             74    72.67
# 1               completed          69             90             88    82.33
# 2                    none          90             95             93    92.67
# 3                    none          47             57             44    49.33
# 4                    none          76             78             75    76.33

# %% [markdown]
# # 2 Value Counts

# %%
# counting gender elements

# len function
len(df_exams['gender'])

# .count() method
df_exams['gender'].count()
# Out:
# 1000

# %%
# counting gender elements by category

df_exams['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# return the relative frequency (divide all values by the sum of values)

df_exams['gender'].value_counts(normalize=True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
# counting "parental level of education" elements by category
df_exams['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
# return the relative frequency and round to 2 decimal

df_exams['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# parental level of education
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: proportion, dtype: float64

# %% [markdown]
# # 3 Sort a dataframe

# %%
# sort by one column

df_exams.sort_values(by='math score') #by is not necessary
df_exams.sort_values('math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 59                     none           0             17             10
# 980                    none           8             24             23
# 17                     none          18             32             28
# 787                    none          19             38             32
# 145                    none          22             39             33
# ..                      ...         ...            ...            ...
# 625               completed         100             97             99
# 623               completed         100             96             86
# 451                    none         100             92             97
# 962                    none         100            100            100
# 149               completed         100            100             93
#
# [1000 rows x 8 columns]

# %%
#sort descending by one column

df_exams.sort_values('math score', ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 962                    none         100            100            100
# 625               completed         100             97             99
# 458                    none         100            100            100
# 623               completed         100             96             86
# 451                    none         100             92             97
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
# [1000 rows x 8 columns]

# %%
# sort descending by multiple columns

#           priority:      1             2 
df_exams.sort_values(['math score', 'reading score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
# [1000 rows x 8 columns]

# %%
# sort descending by multiple columns and update dataframe

df_exams.sort_values(['math score', 'reading score'], ascending=False,
                    inplace=True)
# inplace will make change in the original dataframe

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
# [1000 rows x 8 columns]

# %%
# sort descending with a key function

df_exams.sort_values('race/ethnicity', ascending=True,
                     key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 741                    none          37             57             56
# 151                    none          77             67             68
# 811                    none          45             47             49
# 112                    none          54             53             47
# 25                     none          73             74             72
# ..                      ...         ...            ...            ...
# 751                    none          68             72             65
# 915                    none          68             70             66
# 592                    none          68             68             64
# 479                    none          76             71             67
# 517               completed          66             74             73
#
# [1000 rows x 8 columns]

# %% [markdown]
# # 4 Index

# %% [markdown]
# ## 4.1 create Index

# %%
import numpy as np
import random

# %%
# creating no repeitive values for the index

new_index = np.arange(0, 1000)

# %%
# shuffling the indexes

random.shuffle(new_index)

# %%
# create a new column with new index

df_exams['new_index'] = new_index
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      new_index
# 149        687
# 458        962
# 916         91
# 962        271
# 625        918
# ..         ...
# 145        801
# 787        481
# 17         843
# 980        105
# 59         802
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## 4.2 Set Index

# %%
# set new_index column as index

df_exams.set_index('new_index', inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 687          male        group E          associate's degree  free/reduced
# 962        female        group E           bachelor's degree      standard
# 91           male        group E           bachelor's degree      standard
# 271        female        group E          associate's degree      standard
# 918          male        group D                some college      standard
# ...           ...            ...                         ...           ...
# 801        female        group C                some college  free/reduced
# 481        female        group B                some college      standard
# 843        female        group B            some high school  free/reduced
# 105        female        group B                 high school  free/reduced
# 802        female        group C            some high school  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 687                     completed         100            100             93
# 962                          none         100            100            100
# 91                      completed         100            100            100
# 271                          none         100            100            100
# 918                     completed         100             97             99
# ...                           ...         ...            ...            ...
# 801                          none          22             39             33
# 481                          none          19             38             32
# 843                          none          18             32             28
# 105                          none           8             24             23
# 802                          none           0             17             10
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## 4.3 Sort Index

# %%
# sort dataframe by new index

df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0            male        group A                some college  free/reduced
# 1            male        group C          associate's degree      standard
# 2          female        group C                 high school      standard
# 3            male        group D                 high school  free/reduced
# 4          female        group C            some high school  free/reduced
# ...           ...            ...                         ...           ...
# 995        female        group B           bachelor's degree      standard
# 996        female        group C          associate's degree  free/reduced
# 997        female        group A            some high school  free/reduced
# 998          male        group D                 high school  free/reduced
# 999        female        group C          associate's degree      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 0                            none          58             60             57
# 1                       completed          51             60             58
# 2                            none          66             71             76
# 3                            none          74             70             69
# 4                       completed          71             84             87
# ...                           ...         ...            ...            ...
# 995                          none          61             72             70
# 996                          none          53             61             62
# 997                          none          47             59             50
# 998                     completed          78             77             80
# 999                          none          54             61             58
#
# [1000 rows x 8 columns]

# %%
# sort descending by index

df_exams.sort_index(ascending=False, inplace=True)
