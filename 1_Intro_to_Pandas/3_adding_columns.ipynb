# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('./StudentsPerformance.csv')
df_exams_copy = df_exams.copy()
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1 Adding a new column

# %% [markdown]
# ## 1.1 Adding a new column with a scalar value

# %%
# adding new column to dataframe

df_exams['language score'] = 70

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## 1.2 Adding a new column with an array

# %% [markdown]
# The dataframe has 1000 rows, so we need to create an array with 1000 elements

# %%
import numpy as np

# %%
# create an array of 1000 elements

language_score = np.random.randint(0,101, 1000)

# %%
# length of the array

len(language_score)
# Out:
# 1000

# %%
# creating 1000 random integer between 0 and 100

df_exams['language score'] = language_score

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    language score
# 0              14
# 1              57
# 2              11
# 3              45
# 4              85

# %%
max(df_exams['language score'])
# Out:
# 100

# %%
# create random float numbers between 1 and 100

np.random.uniform(1, 100, 1000)
# Out:
# array([ 4.59694225, 78.86905377, 60.72886548, 66.95137225, 31.47078068,
#        76.36172423, 61.42541069, 57.9927279 , 11.17393906, 42.83581501,
#        34.66576392, 44.5672179 ,  4.37962514,  1.28601293,  6.4843124 ,
#        18.76734626, 35.838354  , 68.44498441, 45.09020094, 92.09736439,
#        51.77193756, 54.54468923,  4.54331843, 47.51412299, 84.3362704 ,
#        30.5371547 , 19.04640642, 24.57885187, 96.02047771,  9.96774216,
#        86.38011927,  2.13603904,  3.42263993, 82.69122923, 73.63272025,
#        90.65059795,  2.40723538, 45.91856105, 89.92900322, 41.17075406,
#        96.41090273, 48.46777237, 10.11462514, 22.92371352, 12.35813385,
#        39.91314502, 83.96231332, 34.61346992, 91.67124387, 97.03165188,
#        53.85145388, 90.12500834, 38.45199138, 20.1677185 , 92.47377504,
#        29.60261529, 32.78410902, 57.17128268, 68.61720297, 19.75992054,
#        81.05541423, 58.27799624, 89.75723562, 72.50191595, 70.2342075 ,
#        27.45584974, 24.97063783, 83.31302865, 61.96687396,  9.39035786,
#        69.42597391, 87.41109211, 33.40314123, 22.19095885, 27.2069637 ,
#        58.54313754, 47.18370965, 20.87119491, 62.29891188, 72.56600626,
#         7.72191441, 18.23413596,  9.32003575, 49.45621553, 60.39522398,
#        84.18339525, 32.94824799,  5.88855314, 12.40300064, 47.18868571,
#        48.98395298, 23.73125457, 57.92109518,  9.74462412, 76.90896137,
#        88.15636987, 46.94419493, 89.76740156, 27.33967123, 55.19679839,
#         9.23795059, 31.56153026,  5.17213572, 44.13563468, 57.89017484,
#        31.27776525, 43.11988182,  5.93365112, 21.23133897, 14.40291081,
#        68.13433516, 70.19366402, 13.95994751, 86.60294192, 71.00115197,
#        56.71094271, 57.96367154, 47.01271703, 49.73290755, 79.81502278,
#        29.36116752, 26.04866228, 21.18115751, 13.13989891, 17.99383813,
#         5.59924913, 74.40116956, 11.20598729, 77.41620311, 71.47646609,
#        98.82984288, 32.56788536, 84.82247437, 74.33516722, 44.03070117,
#        62.40793771, 86.23350693, 59.13710601, 91.07180368,  3.20650484,
#         2.4029461 , 56.93558849, 55.83396719, 78.68891021, 84.97132831,
#        67.02116445, 99.5491415 ,  3.04562859, 28.51122829, 87.26659974,
#        20.21329674, 76.42054242, 61.38042919, 15.04513606, 48.99531245,
#        63.94603324, 50.76850352, 28.93536436, 75.26911633, 87.49763669,
#        72.06520442, 54.10661236, 34.88515825, 97.73168686, 26.3800306 ,
#        68.00235765, 28.92247329, 45.02000305, 77.54710937, 91.77848655,
#        13.988376  , 13.13774922, 12.64057447, 52.77316335, 10.86970771,
#        44.51227221, 89.47889792, 24.61228872, 13.81352612, 50.7077155 ])

# %% [markdown]
# # 2 Adding new column using assign()

# %% [markdown]
# ## 2.1 assign()

# %% [markdown]
# When to use assign?
#     Add mulitple columns in a single line of code.
#     When you need to overwrite the values of an existing columns.
#
#     It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
# Using the unmodified copy dataset

df_exams = df_exams_copy

# %%
# create random numbers for our new score columns

score1 = np.random.randint(1, 100, size=1000)
score2 = np.random.randint(1, 100, size=1000)

# %%
# create a series using the random numbers

series1 = pd.Series(score1, index=np.arange(0, 1000))
series2 = pd.Series(score2, index=np.arange(0, 1000))

# %%
# using assign() to add multiple columns

df_exams = df_exams.assign(score1=series1, score2=series2)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      13
# 1                 completed          69             90             88      47
# 2                      none          90             95             93      24
# 3                      none          47             57             44      45
# 4                      none          76             78             75      92
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      62
# 996                    none          62             55             55      60
# 997               completed          59             71             65      48
# 998               completed          68             78             77      84
# 999                    none          77             86             86      60
#
#      score2
# 0        63
# 1        70
# 2        67
# 3        53
# 4        53
# ..      ...
# 995      78
# 996      13
# 997      86
# 998      40
# 999      18
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 2.2 insert()
# Inserts a new column at a specific position or index

# %%
# using insert() to add a column at a specific position
#             index, name, array
#df_exams.insert(1, 'test', series1)
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    13        group B           bachelor's degree      standard
# 1    female    47        group C                some college      standard
# 2    female    24        group B             master's degree      standard
# 3      male    45        group A          associate's degree  free/reduced
# 4      male    92        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    62        group E             master's degree      standard
# 996    male    60        group C                 high school  free/reduced
# 997  female    48        group C                 high school  free/reduced
# 998  female    84        group D                some college      standard
# 999  female    60        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      13
# 1                 completed          69             90             88      47
# 2                      none          90             95             93      24
# 3                      none          47             57             44      45
# 4                      none          76             78             75      92
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      62
# 996                    none          62             55             55      60
# 997               completed          59             71             65      48
# 998               completed          68             78             77      84
# 999                    none          77             86             86      60
#
#      score2
# 0        63
# 1        70
# 2        67
# 3        53
# 4        53
# ..      ...
# 995      78
# 996      13
# 997      86
# 998      40
# 999      18
#
# [1000 rows x 11 columns]
